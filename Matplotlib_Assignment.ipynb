# %% [markdown]
# # Matplotlib Assignment

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# 1. Matplotlib is one of the library of Python that is used to visualize data.
# 2. It can be used to plot different kind of plots like bargraph,histogram,scatterplot,etc.
# 3. Matplotlib allows programmer to add 'xlabel' and 'ylabel' and also 'title' with grid and it has also a functionality of figure size.
# 4. Five plots that can be plotted using the Pyplot module of Matplotlib are ->
#
# > Line plot --> To plot line plot, plt.plot() is used, it creates a line plot which will help to visualize the data in a very efficient way.
#
# > Bar plot --> This is the simplest of visualizing data which helps to visualize the categorical data with numerical data. plt.bar() can be used to build a barplot using matplotlib.
#
# > Scatter plot --> This is type of plot in which the raw format of data can be visualized. plt.scatter() is used to visualize data in scatter plot.
#
# > Histogram --> Histogram is used to plot the data along with its frequency,it also includes binsize to control the visualisation of data. plt.hist() can be used to visualize histogram in Matplotlib.
#
# > Step plot --> Step plot visualize the data in line format. It only draw the border of that data in the form of steps. plt.step() can be used to visualize the 'step plot'.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Scatter plot is a type of plot in 'matplotlib' in which each value in a data is represented by a dot. It requires two arrays of the same length, one for x-axis and one for y-axis

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,c='#800080',alpha=.5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5])  
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])
fig,axes = plt.subplots(2,2)
axes[0,0].plot(x,y1)
axes[0,1].plot(x,y2)
axes[1,0].plot(x,y3)
axes[1,1].plot(x,y4)


axes[0, 0].set_title('Line 1')
axes[0, 1].set_title('Line 2')
axes[1, 0].set_title('Line 3')
axes[1, 1].set_title('Line 4')


plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# > Bar plots are a type of data visualization used to represent data in the form of rectangular bars. The height of each bar represents the value of a data point, and the width of each bar represents the category of the data.
#
# > Bar plot is used to represent categorical data with its data points

# %%
import matplotlib.pyplot as plt 
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.figure(figsize=(4,3))
plt.bar(company,profit)
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Company\'s Profit')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.figure(figsize=(4,3))
plt.barh(company,profit)
plt.xlabel('Profit')
plt.ylabel('Company')
plt.title('Company\'s Profit')
plt.grid()
plt.show()

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# > Box plots are used to show distribution of numeric data values ,especially when we want to compare multiple groups.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
plt.xlabel('Dataset')
plt.ylabel('Value')
plt.title('Boxplot 1&2')
plt.show()
